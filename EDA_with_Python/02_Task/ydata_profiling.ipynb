# %% [markdown]
# # EDA with Pandas Profiling/YData Profiling

# %%
# step 01: import necessary libraries
import pandas as pd
import seaborn as sns
from ydata_profiling import ProfileReport
#step 02: load the dataset
df = pd.read_csv('Ecommerce_laptops.csv')
#step 03: run pandas profiling and save into html file
profile = ProfileReport(df, title="Ecommerce_laptops 2026 Dataset Profiling Report", explorative=True)
profile.to_file("Ecommerce_laptops_profiling_report_2026.html")
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 60.07it/s]
